# %% [markdown]
# ## Overview of the Dataset

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('./data/old-spanish-corpus-chunked.tsv', sep='\t', dtype={'date': str})
df
# Out:
# C:\Users\santi\AppData\Local\Temp\ipykernel_6044\428079709.py:1: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/old-spanish-corpus-chunked.tsv', sep='\t', dtype={'date': str})
#                       source source_id source_text_id  chunk_id  \
# 0        The British Library   3436138              9         0
# 1        The British Library   3436138             10         0
# 2        The British Library   3436138             11         0
# 3        The British Library   3436138             12         0
# 4        The British Library   3436138             12         1
# ...                      ...       ...            ...       ...
# 1141485    Project Gutenberg     53294            916         0
# 1141486    Project Gutenberg     53294            917         0
# 1141487    Project Gutenberg     53294            919         0
# 1141488    Project Gutenberg     53294            920         0
# 1141489    Project Gutenberg     53294            921         0
#
#                                                      title       date   place  \
# 0        Historia de la conquista de México, etc [With ...       1809  London
# 1        Historia de la conquista de México, etc [With ...       1809  London
# 2        Historia de la conquista de México, etc [With ...       1809  London
# 3        Historia de la conquista de México, etc [With ...       1809  London
# 4        Historia de la conquista de México, etc [With ...       1809  London
# ...                                                    ...        ...     ...
# 1141485                         Recuerdos Del Tiempo Viejo  1817-1893       ?
# 1141486                         Recuerdos Del Tiempo Viejo  1817-1893       ?
# 1141487                         Recuerdos Del Tiempo Viejo  1817-1893       ?
# 1141488                         Recuerdos Del Tiempo Viejo  1817-1893       ?
# 1141489                         Recuerdos Del Tiempo Viejo  1817-1893       ?
#
#                                                       text
# 0        HISTORIA DE LA CONQUISTA PE MÉXICO, POBLACIÓN ...
# 1        This Work, as well as LAS FÁBULAS LITERARIAS, ...
# 2        HISTORIA De la Conquista, población y Progreso...
# 3        CONQUISTA quartel observando la batalla, y rec...
# 4        Pon deró con afectada seguridad el atrevimient...
# ...                                                    ...
# 1141485  Pero amo á Barcelona por tiranía     de ley in...
# 1141486  Barcelona trabaja... y á su existencia     el ...
# 1141487  Olvidaba que entre ambas hay diferencia:     n...
# 1141488  La diferencia es esta: pero es preciso     que...
# 1141489  _Esta obra es propiedad de su Autor, el que pe...
#
# [1141490 rows x 8 columns]

# %%
source_counts = df['source'].value_counts(normalize=True) * 100

plt.figure(figsize=(3.70, 6))
colors = ['blue', 'green', 'red', 'purple', 'orange']
bar_width = 0.8
x_positions = range(len(source_counts))

for i, (source, count) in enumerate(source_counts.items()):
    plt.bar(x_positions[i], count, color=colors[i % len(colors)], width=bar_width, label=source)
    plt.text(x_positions[i], count + 1, f'{count:.1f}%', ha='center', va='bottom')

plt.title('Corpus Source Distribution')
plt.ylim(0, 100)
plt.gca().axes.get_xaxis().set_visible(False)
plt.gca().set_yticklabels([f'{int(x)}%' for x in plt.gca().get_yticks()])
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig('./imgs/corpus-source-distribution.png')
plt.show()
# Out:
# C:\Users\santi\AppData\Local\Temp\ipykernel_6044\1611968651.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels([f'{int(x)}%' for x in plt.gca().get_yticks()])

# %%
df['date_low'] = df['date'].str.split('-').str[0]
df['date_low'] = df['date_low'].astype(int)
df['date_high'] = df['date'].apply(lambda x: x.split('-')[1] if len(x.split('-')) == 2 else x.split('-')[0])
df['date_high'] = df['date_high'].astype(int)

# %%
print(f"\ndates: {df['date_low'].min()} - {df['date_high'].max()}")
# Out:
# dates: 1800 - 1914

# %%
df['selected_date'] = df.apply(lambda row: row['date_low'] if 1800 <= row['date_low'] <= 1914 else row['date_high'], axis=1)

df['decade'] = df['selected_date'] // 10 * 10

decade_counts = df['decade'].value_counts(normalize=True) * 100

# Plotting
plt.figure(figsize=(5.5, 6))
bars = decade_counts.sort_index().plot(kind='bar', color='skyblue')
plt.title('Corpus Decade Distribution')
plt.xlabel('Decade')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

for bar, count in zip(bars.patches, decade_counts.sort_index()):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.2, f'{count:.1f}%', ha='center', va='bottom')

plt.tight_layout()
plt.savefig('./imgs/corpus-decade-distribution.png')
plt.show()
